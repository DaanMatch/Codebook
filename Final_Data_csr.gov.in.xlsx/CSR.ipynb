# %%
import pandas as pd
import numpy as np

# %%
# !ls
# Out:
# CSR.ipynb                        Final_Data_csr.gov.in.xlsx.ipynb
# Final_Data_csr.gov.in.xlsx

# %%
df = pd.read_excel("Final_Data_csr.gov.in.xlsx")
df.head()
# Out:
#                                                  Url  \
# 0  https://csr.gov.in/companyprofile/dashboard.ph...
# 1  https://csr.gov.in/companyprofile/dashboard.ph...
# 2  https://csr.gov.in/companyprofile/dashboard.ph...
# 3  https://csr.gov.in/companyprofile/dashboard.ph...
# 4  https://csr.gov.in/companyprofile/dashboard.ph...
#
#                                         Company Name Date of Incorporation  \
# 0  International Market Assessment (india)private...            1996-03-19
# 1                     Intellect Design Arena Limited            2011-04-18
# 2                        Coral Drugs Private Limited            1993-12-22
# 3                  Renew Akshay Urja Private Limited            2015-01-19
# 4      Mahakaushal Sugar And Power Industrieslimited            2005-04-13
#
#      Class          RoC                   Category      Sub Category  \
# 0  Private    RoC-Delhi  Company limited by Shares  Non-govt company
# ...
