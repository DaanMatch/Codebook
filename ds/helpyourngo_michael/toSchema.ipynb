# %% [markdown]
# # Schema
#
# https://docs.google.com/document/d/1wDCb29oYVJIF2RPNtrnzxEYs1lH0J4RwYACDIn4kPhA/edit#heading=h.4wl6nl945n7g

# %%
import pandas as pd
import validators
import uuid
# !ls
# Out:
# Untitled.ipynb   helpyourngo.sql  random.txt
# helpyourngo.json lab1.ipynb

# %%
NgoBackground = pd.DataFrame(columns=[
    'ngoId', 
    'hasRegistration', 
    'hasFinance',
    'logo', 
    'yearEstablished', 
    'missionStatement', 
    'vision', 
    'objectives', 
    'legalStatus', 
    'areasOfOperation', 
    'activeStatus'
])
NgoRegistration = pd.DataFrame(columns=[
    'ngoId',
    'isRegistrationFor',
    'ngoType',
    'regNo',
    'regDate',
    'registrar',
    '12ANo',
    '12ARegdate',
    '12AUpload',
    '80GNo',
    '80GRegdate',
    '80GUpload',
    '35ACNo',
    '35ACRegdate',
    '35ACUpload',
    'fCRANo',
    'fCRARegdate',
    'natureListed',
    'fCRAStatus',
    'fCRAExpiration',
    'fCRAUpload',
    'pan',
    'tan',
    'gst',
    'notes'
])

NgoContact = pd.DataFrame(columns=[
    'ngoId',
    'ngoName',
    'orgEmail',
    'officePhone',
    'primaryPoc',
    'primaryPocPhone',
    'secondaryPoc',
    'secondaryPocPhone',
    'mailingAddress',
    'physicalAddress',
    'fieldOffices',
    'orgType',
    'orgWebsite',
    'websiteIsValid',
    'facebook',
    'twitter',
    'iInstagram',
    'youtube',
    'whatsapp',
    'otherSocials',
    'scrapeSource',
    'executiveDirector',
    'technicalSupport',
    'chairmanName',
    'chairmanMobile',
    'chairmanEmail',
    'viceChairmanName',
    'viceChairmanMobile',
    'viceChairmanEmail',
    'secretaryName',
    'secretaryMobile',
    'secretaryEmail',
    'assistantSecretaryName',
    'assistantSecretaryMobile',
    'assistantSecretaryEmail'
])

NgoFinance = pd.DataFrame(columns=[
    'ngoId',
    'fiscalYear',
    'totalIncome',
    'totalGrant',
    'totalExpense',
    'totalAssets',
    'totalLiabilities',
    'totalFundingGap',
    'sourceOfFunds',
    'majorFunders',
    'ngoBudgetAllocation',
    'ngoBudgetUtilization',
    'auditReport',
    'avgMonthlyExpenditure',
    'avgMonthlyOverhead',
    'longTermLoan',
    'fulltimeEmployees',
    'parttimeEmployees',
    'employmentExpenses',
    'fulltimeVolunteers',
    'parttimeVolunteers',
    'volunteerExpenses',
    'consultants',
    'consultantExpenses',
    'occupancyExpenses',
    'fundraisingExpenses'
])

# %%
df = pd.read_json("helpyourngo.json")
df["name"] = df["name"].str.title()
df = df.dropna(subset=['name'])
df["ngoId"] = [uuid.uuid3(uuid.NAMESPACE_URL, _) for _ in df["name"]]
df.head()
# Out:
#                                       name  last_updated  \
# 0                            Aai Caretaker        2020.0
# 1                                  Aakriti        2015.0
# 2               Aakash Maindwal Foundation        2016.0
# 3                        Aaradhana Sanstha        2013.0
# 4  Action Against Hunger (Fight Hunger ...        2019.0
#
#                                    address             mobile  \
# 0  Room No. B/4, Ashok Nagar, Near Kris...    +91 22 25530537
# 1  J-159, Sector-10 DLF, Faridabad 1210...     +91 9312263021
# 2  107, First Floor, Block - Milano, Ma...    +91 120 4377527
# 3  14, Sulabhpuram, Sikandara Bodla Roa...     +91 9639161612
# 4  201, Sai Prasad Building, Sion Kamga...  +91 022 2611 1275
#
#                                 email                     website  \
# 0            info@aaicaretaker.org.in         www.aaicaretaker.in
# 1              aakritischool@yahoo.in          www.aakritingo.org
# 2  aakashmaindwalfoundation@gmail.com            www.amfindia.org
# 3              drhchaudhary@yahoo.com                        None
# 4   contact@fighthungerfoundation.org  www.actionagainsthunger.in
#
#   annual_expenditure                              description  \
# 0        138,990,084  Aai Caretaker is involved in diverse...
# 1          1,023,204  A parent-initiative, Association for...
# 2            767,980  Aakash Maindwal Foundation has been ...
# 3               None  Aaradhana Sanstha was formed for edu...
# 4         86,348,954  Action Against Hunger (AAH) register...
#
#                                   ngoId
# 0  608f2a51-35a5-3002-8229-c078531a7cdd
# 1  c894bc4b-4c34-38ca-a874-fa9f9bc69677
# 2  b023c29c-3ae0-3128-881c-b0245892e0aa
# 3  7c8e8ac2-e381-3a90-bf13-c3786b890a05
# 4  3e5c857a-4e60-36d9-b3a3-d14c02bf373b

# %%
df.columns
# Out:
# Index(['name', 'last_updated', 'address', 'mobile', 'email', 'website',
#        'annual_expenditure', 'description', 'ngoId'],
#       dtype='object')

# %%
# Set display option to show full text
pd.set_option('display.max_colwidth', 40)
print(df.description[:1])
# Out:
# 0    Aai Caretaker is involved in diverse...
# Name: description, dtype: object

# %%
# Mapping for NgoContact
NgoContact["ngoId"] = df['ngoId']
NgoContact["ngoName"] = df["name"].str.title()
NgoContact["orgEmail"] = df["email"]
NgoContact["officePhone"] = df["mobile"]
NgoContact["physicalAddress"] = df["address"]
NgoContact["orgWebsite"] = df["website"]

def validate_url(url):
    if pd.isna(url):  # handle NaN values
        return False
    if validators.url(url):
        return True
    else:
        return False

NgoContact['websiteIsValid'] = NgoContact['orgWebsite'].apply(validate_url)
NgoContact['scrapeSource'] = 'helpyourngo'

# Mapping for NgoFinance
NgoFinance["ngoId"] = df['ngoId']
NgoFinance["fiscalYear"] = df['last_updated'].astype(int)
NgoFinance['totalExpense'] = df['annual_expenditure']
#NgoFinance['avgMonthlyExpenditure'] = df['annual_expenditure']/12

# Mapping for NgoBackground
NgoBackground["ngoId"] = df['ngoId']
NgoBackground["objectives"] = df["description"]
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipykernel_13961/2827837791.py in <module>
#      20 # Mapping for NgoFinance
#      21 NgoFinance["ngoId"] = df['ngoId']
# ---> 22 NgoFinance["fiscalYear"] = df['last_updated'].astype(int)
#      23 NgoFinance['totalExpense'] = df['annual_expenditure']
#      24 #NgoFinance['avgMonthlyExpenditure'] = df['annual_expenditure']/12
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     590         values = self.values
#     591
# --> 592         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     593
#     594         new_values = maybe_coerce_values(new_values)
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1166
#    1167     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1168         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1169
#    1170     elif is_object_dtype(arr):
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1211     """
#    1212     if not np.isfinite(values).all():
# -> 1213         raise IntCastingNaNError(
#    1214             "Cannot convert non-finite values (NA or inf) to integer"
#    1215         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
NgoFinance
# Out:
#                                     ngoId  fiscalYear totalIncome totalGrant  \
# 0    608f2a51-35a5-3002-8229-c078531a7cdd      2020.0         NaN        NaN
# 1    c894bc4b-4c34-38ca-a874-fa9f9bc69677      2015.0         NaN        NaN
# 2    b023c29c-3ae0-3128-881c-b0245892e0aa      2016.0         NaN        NaN
# 3    7c8e8ac2-e381-3a90-bf13-c3786b890a05      2013.0         NaN        NaN
# 4    3e5c857a-4e60-36d9-b3a3-d14c02bf373b      2019.0         NaN        NaN
# ..                                    ...         ...         ...        ...
# 683  ad3c358b-78d3-3f35-9d8d-0e97a1289d66      2020.0         NaN        NaN
# 684  fcc289bc-24ea-32b6-9853-9d1bbd7ec893      2015.0         NaN        NaN
# 685  1dcb89b0-98e3-39ea-9511-c474d4dbeabf      2015.0         NaN        NaN
# 686  9054faca-dec0-3e34-be0c-0924cb30a75f      2014.0         NaN        NaN
# 687  a6fbde2a-e4f2-340f-87d6-30725e0a9e4a      2014.0         NaN        NaN
#
#     totalExpense totalAssets totalLiabilities totalFundingGap sourceOfFunds  \
# 0    138,990,084         NaN              NaN             NaN           NaN
# 1      1,023,204         NaN              NaN             NaN           NaN
# 2        767,980         NaN              NaN             NaN           NaN
# 3           None         NaN              NaN             NaN           NaN
# 4     86,348,954         NaN              NaN             NaN           NaN
# ..           ...         ...              ...             ...           ...
# 683      903,612         NaN              NaN             NaN           NaN
# 684    7,907,718         NaN              NaN             NaN           NaN
# 685    9,493,108         NaN              NaN             NaN           NaN
# 686    2,473,686         NaN              NaN             NaN           NaN
# 687    4,558,280         NaN              NaN             NaN           NaN
#
#     majorFunders  ... fulltimeEmployees parttimeEmployees employmentExpenses  \
# 0            NaN  ...               NaN               NaN                NaN
# 1            NaN  ...               NaN               NaN                NaN
# 2            NaN  ...               NaN               NaN                NaN
# 3            NaN  ...               NaN               NaN                NaN
# 4            NaN  ...               NaN               NaN                NaN
# ..           ...  ...               ...               ...                ...
# 683          NaN  ...               NaN               NaN                NaN
# 684          NaN  ...               NaN               NaN                NaN
# 685          NaN  ...               NaN               NaN                NaN
# 686          NaN  ...               NaN               NaN                NaN
# 687          NaN  ...               NaN               NaN                NaN
#
#     fulltimeVolunteers parttimeVolunteers volunteerExpenses consultants  \
# 0                  NaN                NaN               NaN         NaN
# 1                  NaN                NaN               NaN         NaN
# 2                  NaN                NaN               NaN         NaN
# 3                  NaN                NaN               NaN         NaN
# 4                  NaN                NaN               NaN         NaN
# ..                 ...                ...               ...         ...
# 683                NaN                NaN               NaN         NaN
# 684                NaN                NaN               NaN         NaN
# 685                NaN                NaN               NaN         NaN
# 686                NaN                NaN               NaN         NaN
# 687                NaN                NaN               NaN         NaN
#
#     consultantExpenses occupancyExpenses fundraisingExpenses
# 0                  NaN               NaN                 NaN
# 1                  NaN               NaN                 NaN
# 2                  NaN               NaN                 NaN
# 3                  NaN               NaN                 NaN
# 4                  NaN               NaN                 NaN
# ..                 ...               ...                 ...
# 683                NaN               NaN                 NaN
# 684                NaN               NaN                 NaN
# 685                NaN               NaN                 NaN
# 686                NaN               NaN                 NaN
# 687                NaN               NaN                 NaN
#
# [688 rows x 26 columns]

# %%
# Drop rows where all columns are empty except Id
NgoContact = NgoContact.dropna(how='all', subset=NgoContact.columns.difference(['ngoId']))
NgoRegistration = NgoRegistration.dropna(how='all', subset=NgoRegistration.columns.difference(['ngoId']))
NgoFinance = NgoFinance.dropna(how='all', subset=NgoRegistration.columns.difference(['ngoId']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_13961/2865374647.py in <module>
#       3 NgoContact = NgoContact.dropna(how='all', subset=NgoContact.columns.difference(['ngoId']))
#       4 NgoRegistration = NgoRegistration.dropna(how='all', subset=NgoRegistration.columns.difference(['ngoId']))
# ----> 5 NgoFinance = NgoFinance.dropna(how='all', subset=NgoRegistration.columns.difference(['ngoId']))
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /Applications/JupyterLab.app/Contents/Resources/jlab_server/lib/python3.8/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5951             check = indices == -1
#    5952             if check.any():
# -> 5953                 raise KeyError(list(np.compress(check, subset)))
#    5954             agg_obj = self.take(indices, axis=agg_axis)
#    5955
#
# KeyError: ['12ANo', '12ARegdate', '12AUpload', '35ACNo', '35ACRegdate', '35ACUpload', '80GNo', '80GRegdate', '80GUpload', 'fCRAExpiration', 'fCRANo', 'fCRARegdate', 'fCRAStatus', 'fCRAUpload', 'gst', 'isRegistrationFor', 'natureListed', 'ngoType', 'notes', 'pan', 'regDate', 'regNo', 'registrar', 'tan']
